# %%
pwd
# Out:
# 'C:\\Users\\SMART-09\\lee'

# %%
import numpy as np

# %%
np.linspace(0,1,num=10)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %%
np.random.random(10)*100
# Out:
# array([ 1.33854695, 97.11729821,  0.77844221, 90.10858941, 25.69331052,
#        15.95896714, 43.23913621, 41.76367674, 73.60879178, 45.60727971])

# %%
import pandas as pd

# %%
pd.read_csv("C:/Users/SMART-09/lee/kopo_product_volume.csv")
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 0        A01       ST0002    201512   151750
# 1        A01       ST0001    201520   645626
# 2        A01       ST0002    201520   125863
# 3        A01       ST0001    201515   810144
# 4        A01       ST0002    201515   128999
# 5        A01       ST0001    201518   671464
# 6        A01       ST0002    201518   134467
# 7        A01       ST0001    201513   470040
# 8        A01       ST0002    201513   140297
# 9        A01       ST0001    201511   524787
# 10       A01       ST0002    201511   145509
# 11       A01       ST0001    201516   764927
# 12       A01       ST0002    201516   140313
# 13       A01       ST0001    201519   682757
# 14       A01       ST0002    201519   128668
# 15       A01       ST0001    201514   428195
# 16       A01       ST0002    201514   137488
# 17       A01       ST0001    201512   486509
# 18       A01       ST0001    201517   697502
# 19       A01       ST0002    201517   127163
# ...

# %%
pd.read_csv("./kopo_product_volume.csv",encoding="ms949")
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 0        A01       ST0002    201512   151750
# 1        A01       ST0001    201520   645626
# 2        A01       ST0002    201520   125863
# 3        A01       ST0001    201515   810144
# 4        A01       ST0002    201515   128999
# 5        A01       ST0001    201518   671464
# 6        A01       ST0002    201518   134467
# 7        A01       ST0001    201513   470040
# 8        A01       ST0002    201513   140297
# 9        A01       ST0001    201511   524787
# 10       A01       ST0002    201511   145509
# 11       A01       ST0001    201516   764927
# 12       A01       ST0002    201516   140313
# 13       A01       ST0001    201519   682757
# 14       A01       ST0002    201519   128668
# 15       A01       ST0001    201514   428195
# 16       A01       ST0002    201514   137488
# 17       A01       ST0001    201512   486509
# 18       A01       ST0001    201517   697502
# 19       A01       ST0002    201517   127163
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
#1,20 사이에 2개의 점을 생성한다.
x = np.linspace(1,20,2)
# y= x의 제곱
y = x**2
#시각화
plt.plot(x,y)
#도표 제목
plt.title("test")
# Out:
# Text(0.5,1,'test')

# %%
#0과 5사이에 11개의 점을 생성한다.
x = np.linspace(0,5,11)
y = x**2
plt.plot(x,y)
plt.title("wow")
# Out:
# Text(0.5,1,'wow')

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

font_name = matplotlib.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
matplotlib.rc('font', family=font_name)
print(font_name)
# Out:
# Malgun Gothic

# %%
x = np.linspace(0,5,11)
y = x**2
plt.plot(x,y)
plt.title('섭')
# Out:
# Text(0.5,1,'섭')

# %%
a=5
b=17
print(a+b)
# Out:
# 22

# %%
sum=a+b
a=5
b=18
print(sum)
# Out:
# 22

# %%
#mod = 나머지연산
mod=a%b
a=19
b=5
print(mod)
# Out:
# 5

# %%
#제곱연산
outcome=a**b
a=5
b=23
print(outcome)
# Out:
# 2476099

# %%
#더하기
a=5
b=26
sum=a+b
print(sum)
# Out:
# 31

# %%
pwd
# Out:
# 'C:\\Users\\SMART-09\\lee'

# %%
import numpy as np

# %%
np.linspace(0,200,num=5)
# Out:
# array([  0.,  50., 100., 150., 200.])

# %%
np.random.random(5)*100
# Out:
# array([ 1.86829734, 96.7272213 , 98.1244614 , 12.98801932, 76.08341441])
