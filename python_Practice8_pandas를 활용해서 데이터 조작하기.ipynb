# %% [markdown]
# ### 1. 자료 불러오기

# %%
import pandas as pd
customerData = pd.read_csv('../lee/Python_ST_EX/dataset/customerdata.csv')
answer1 = customerData[(customerData.EMI == 3) & (customerData.DEVICECOUNT > 5)]
answer1
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE            CUSTTO
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27   F17131  3179.708359    3          6.5    1.100000        Early-bird
# 33   G16437  3787.328898    3          6.7    1.000000        Early-bird
# 36   G18402  3402.199381    3          6.5    1.000000        Early-bird
# 40   H16326  3988.935304    3          6.5    0.900000        Early-bird
# 45   I12899  3018.895637    3          6.4    0.900000        Early-bird
# 51   J10809  3676.135627    3          6.5    0.800000        Early-bird
# 52   J15083  2811.265932    3          6.0    0.900000        Early-bird
# 53   J16445  3041.848186    3          6.4    0.800000        Early-bird
# 60   L13892  3263.515145    3          6.7    1.100000        Early-bird
# 67   N13273  3839.694732    3          6.9    1.100000        Early-bird
# 95   R16364  3592.353540    3          6.2    0.900000        Early-bird
# ...

# %% [markdown]
# ### 2. 불러온 자료의 data타입 조회하기

# %%
customerData.dtypes
# Out:
# CUSTID          object
# AVGPRICE       float64
# EMI              int64
# DEVICECOUNT    float64
# PRODUCTAGE     float64
# CUSTTO          object
# dtype: object

# %%
customerData["DEVICECOUNT"]=customerData["DEVICECOUNT"].astype(int) 
#데이터.컬럼명 = 데이터.컬럼명.astype() 도 가능.

# %% [markdown]
# ### 3. 데이터 불러오는거 실습

# %%
selloutData = pd.read_csv('../lee/Python_ST_EX/dataset/kopo_customerdata.csv')
answer2 = selloutData[(selloutData.GENDER == "Male") &
                      (selloutData.EMAIL > 0)]
#불러오려는 데이터의 데이터타입이 문자열일시 " "로 감싸주어야 함.
answer2.head(9)
# Out:
#      CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0         1503989    State2   2   Male    0        1      1         0
# 16        1154228    State2   2   Male    0        1      1         0
# 81         393246    State2   2   Male    0        1      1         1
# 206       2532568    State2   2   Male    1        1      1         0
# 216        487928    State2   2   Male    0        1      1         0
# 226       2452240    State2   2   Male    1        1      1         1
# 299       1295854    State2   2   Male    1        1      1         2
# 308        554757    State2   2   Male    0        1      1         0
# 330        761018    State2   2   Male    1        1      1         0
#
#      TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0           30300          0      30300          0              0           0
# 16          18200          0          0      18200              0           0
# ...

# %%
selloutData.dtypes
# Out:
# CUSTOMERCODE      int64
# STATENAME        object
# ST                int64
# GENDER           object
# DOB               int64
# GENDER1           int64
# EMAIL             int64
# FEST_CNT          int64
# TOTAL_AMOUNT      int64
# AC_AMOUNT         int64
# AV_AMOUNT         int64
# HA_AMOUNT         int64
# EMI_CE_AMOUNT     int64
# IS_HIGHEND        int64
# CNT_VIST          int64
# GAP_VISIT         int64
# dtype: object

# %%
targetGender = "Female"

# %%
targetEmail = 0

# %%
selloutData = pd.read_csv('../lee/Python_ST_EX/dataset/kopo_customerdata.csv')
answer2 = selloutData[(selloutData.GENDER == targetGender) &
                      (selloutData.EMAIL > targetEmail)]
#불러오려는 데이터의 데이터타입이 문자열일시 " "로 감싸주어야 함.
answer2.head(5)
# Out:
#       CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 161        1903089    State2   2  Female    1        2      1         3
# 901        1130773    State2   2  Female    1        2      1         0
# 1188        384925    State2   2  Female    0        2      1         1
# 1248       1439246    State2   2  Female    1        2      1         1
# 1592       2244756    State2   2  Female    1        2      1         1
#
#       TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# 161         101500      47000      54500          0              0
# 901          70900          0      70900          0              0
# 1188         70600          0      70600          0              0
# 1248         59600      42900          0      16700              0
# 1592         28300          0          0      28300              0
#
#       IS_HIGHEND  CNT_VIST  GAP_VISIT
# 161            0         4        354
# 901            0         1          0
# ...

# %% [markdown]
# ### 4. 데이터 불러오기 실습2

# %%
targetGroup = "st0002"
targetVol = 300000

# %%
productData = pd.read_csv('../lee/Python_ST_EX/dataset/kopo_product_volume.csv')
answer3 = productData[(productData.PRODUCTGROUP == targetGroup.upper())&
                      (productData.VOLUME > targetVol)]
answer3.head(7)
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 80       A01       ST0002    201452   422468
# 86       A01       ST0002    201451   356271
# 90       A01       ST0002    201449   669711
# 94       A01       ST0002    201447   378339
# 102      A01       ST0002    201448  1400339
# 196      A01       ST0002    201552   422468
# 208      A01       ST0002    201551   356271

# %%
productData = pd.read_csv('../lee/Python_ST_EX/dataset/kopo_product_volume.csv')
answer3 = productData.query("PRODUCTGROUP == 'ST0002' and VOLUME > 300000")
answer3.head(7)
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 80       A01       ST0002    201452   422468
# 86       A01       ST0002    201451   356271
# 90       A01       ST0002    201449   669711
# 94       A01       ST0002    201447   378339
# 102      A01       ST0002    201448  1400339
# 196      A01       ST0002    201552   422468
# 208      A01       ST0002    201551   356271
