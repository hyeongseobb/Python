# %%
import requests #Used to service API connection
from lxml import html #Used to parse XML
from bs4 import BeautifulSoup #Used to read XML table on webpage
import pandas as pd
from common import cFunction as cf
import numpy as np
import wget

# get dataList from filesystem to load and write
#dataList = pd.read_excel("../../data/inbound/dataList.xlsx")

# get dataList from spreadsheet to load and write
dataList = pd.read_csv("https://docs.google.com/spreadsheets/d/1VngqG-m7G8k1587c21MZoheR1Fz3amp1mJtiBvA1Jb0/export?format=csv&gid=0")
print("### The total number of target data is " + str(len(dataList)))

# Filtering -> get dataList only defined url
dataList = dataList[   dataList['사이트'].notnull() ]
print(dataList[["사이트"]])
print("### The total number of filtered data is " + str(len(dataList)))

##################################################
# Filtering -> for your own object
#dataList = dataList[   dataList['번호'] == "352" ]
##################################################

# create folder to save result
outPath = "../../data/outbound/"
folderList = dataList["폴더명"].tolist()
for i in folderList:
    cf.createFolder(outPath+i)

dataList = dataList.fillna("")
dataList = dataList.reset_index(drop=True)

# get dataList to load and write
for dataCount in range(0,len(dataList)):

    inputUrl = dataList.loc[dataCount, "사이트"]
    inputKey = dataList.loc[dataCount, "서비스키"]
    inputParameter = dataList.loc[dataCount, "파라미터"]
    inputFolder = dataList.loc[dataCount, "폴더명"]
    inputFile = dataList.loc[dataCount, "서비스명"]
    inputDataType = dataList.loc[dataCount, "데이터타입"]
    inputRefUrl = dataList.loc[dataCount, "참고문서"]
    inputRefType = dataList.loc[dataCount, "참고문서타입"]
    print(inputUrl)

    url = cf.makeURL(inputUrl,inputKey,inputParameter)
    print("fullUrl is " + url)

    newDF = pd.DataFrame()
    if (inputDataType == "xml"):
        newDF = cf.xmlProcess(url)
    elif(inputDataType == "json"):
        newDF = cf.jsonProcess(url)
    elif(inputDataType == "csv"):
        newDF = cf.csvProcess(url)

    fullOutPath = outPath+inputFolder+"/"+inputFolder+inputFile+".csv"
    print(fullOutPath)

    try:
        newDF.to_csv(fullOutPath, index=False, encoding="ms949")
    except Exception as x:
        print(x)

    fullOutRefPath = outPath + inputFolder + "/" + inputFolder + inputFile + "."+inputRefType
    try:
        wget.download(inputRefUrl, fullOutRefPath)
    except Exception as e:
        print(inputFolder+"참고문서 Error")
        print(e)
        pass
# Out:
# ### The total number of target data is 416
#                                                    사이트
# 305  https://www.data.go.kr/dataset/fileDownload.do...
# 306  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 341  http://fsc.go.kr/info/trd_list.jsp?menu=723000...
# 351  http://openapi.molit.go.kr/OpenAPI_ToolInstall...
# 354  https://www.data.go.kr/dataset/fileDownload.do...
# 358  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 359  http://api.hf.go.kr:8090/service/rest/HfMbsInt...
# 360  http://api.hf.go.kr:8090/service/rest/HfMbbInt...
# 362  https://www.data.go.kr/dataset/fileDownload.do...
# 377  https://www.data.go.kr/dataset/fileDownload.do...
# 384  https://www.data.go.kr/dataset/fileDownload.do...
# 385  https://www.data.go.kr/pubn/dat/IrosUseData/de...
# 388  https://www.data.go.kr/subMain.jsp#/L3B1YnIvcG...
# 389  https://www.data.go.kr/subMain.jsp#/L3B1YnIvcG...
# ### The total number of filtered data is 14
# https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001439364&fileDetailSn=1&publicDataDetailPk=uddi:2438e83c-e8a6-41b2-b1e1-d536ac75ffc6
# fullUrl is https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001439364&fileDetailSn=1&publicDataDetailPk=uddi:2438e83c-e8a6-41b2-b1e1-d536ac75ffc6
# ../../data/outbound/306_한국감정원 오피스텔 동향조사 현황/306_한국감정원 오피스텔 동향조사 현황.csv
# 306_한국감정원 오피스텔 동향조사 현황참고문서 Error
# unknown url type: ''
# http://openapi.kab.co.kr/OpenAPI_ToolInstallPackage/service/rest/TradePrcIndexSvc/getTradePrcIndex?startmonth=201402&endmonth=201403&region=11000&buildingtype=3&serviceKey=
# fullUrl is http://openapi.kab.co.kr/OpenAPI_ToolInstallPackage/service/rest/TradePrcIndexSvc/getTradePrcIndex?startmonth=201402&endmonth=201403&region=11000&buildingtype=3&serviceKey=rQjRsn9x24ghbU%2B9%2Bsd3qTdMwCjZifdkuvjnjQ%2FKdKaARRpDQ2foOTgr4MyUwIuF5TND%2FX9agsHsuWcDdNYf7w%3D%3D
#   aptTypeNm regionCd regionNm                    rsRow
# 0    연립/다세대    11000       서울  201402,95.8|201403,95.8
# ../../data/outbound/307_한국감정원 부동산 매매가격지수 현황/307_한국감정원 부동산 매매가격지수 현황.csv
# 307_한국감정원 부동산 매매가격지수 현황참고문서 Error
# unknown url type: ''
# http://fsc.go.kr/info/trd_list.jsp?menu=7230000&bbsid=BBS0069
# fullUrl is http://fsc.go.kr/info/trd_list.jsp?menu=7230000&bbsid=BBS0069
# ../../data/outbound/342_금융시장동향/342_금융시장동향.csv
# 342_금융시장동향참고문서 Error
# unknown url type: ''
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?
# fullUrl is http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D&LAWD_CD=11110&DEAL_YMD=201512
#          거래금액  건축년도     년      도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드 도로명일련번호코드  \
# 0      82,500  2008  2015    사직로8길      00004      00000    11110        03
# 1      60,000  1981  2015  세종대로23길      00047      00000    11110        02
# 2     130,000  2004  2015    경희궁2길      00005      00005    11110        01
# 3     105,000  2004  2015    사직로8길      00024      00000    11110        05
# 4     120,000  2003  2015    사직로8길      00020      00000    11110        05
# 5      17,000  2014  2015      대학로      00047      00000    11110        05
# 6      17,000  2014  2015      대학로      00047      00000    11110        05
# 7      57,000  2006  2015   혜화로3가길      00030      00000    11110        01
# 8      44,000  1995  2015     창경궁로      00265      00000    11110        07
# 9      52,000  1995  2015     창경궁로      00265      00000    11110        07
#
#   도로명지상지하코드    도로명코드 ... 법정동읍면동코드 법정동지번코드                    아파트   월      일  \
# 0         0  4100135 ...    11500       1  광화문풍림스페이스본(101동~105동)  12   1~10
# 1         0  4100190 ...    11700       1             롯데미도파광화문빌딩  12  21~31
# 2         0  4100005 ...    11800       1                   킹스매너  12   1~10
# 3         0  4100135 ...    11800       1              경희궁의아침2단지  12  11~20
# 4         0  4100135 ...    11800       1              경희궁 파크팰리스  12  21~31
# 5         0  3100002 ...    16600       1                  이화에수풀  12  11~20
# 6         0  3100002 ...    16600       1                  이화에수풀  12  11~20
# 7         0  4100544 ...    17000       1                    렉스빌  12  21~31
# 8         0  3005008 ...    17100       1                    아남1  12   1~10
# 9         0  3005008 ...    17100       1                    아남1  12   1~10
#
#          일련번호    전용면적      지번   지역코드   층
# 0  11110-2203   94.51       9  11110  11
# 1    11110-12  149.95     145  11110   8
# 2   11110-118  194.43  110-15  11110   6
# 3   11110-115  124.17      71  11110   8
# 4   11110-107  146.33      95  11110   4
# 5  11110-2359   16.98  195-10  11110   8
# 6  11110-2359   16.98  195-10  11110   4
# 7   11110-973  106.98      19  11110   3
# 8    11110-25    84.8       4  11110  18
# 9    11110-25    84.9       4  11110  12
#
# [10 rows x 24 columns]
# ../../data/outbound/352_한국감정원 아파트 실거래가격지수/352_한국감정원 아파트 실거래가격지수.csv
# 100% [........................................................] 251392 / 251392https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001308262&fileDetailSn=1&publicDataDetailPk=uddi:158df915-7adf-4c50-904f-c9e77286f52e
# fullUrl is https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001308262&fileDetailSn=1&publicDataDetailPk=uddi:158df915-7adf-4c50-904f-c9e77286f52e
# ../../data/outbound/355_한국감정원 토지거래 현황/355_한국감정원 토지거래 현황.csv
# 355_한국감정원 토지거래 현황참고문서 Error
# unknown url type: ''
# http://openapi.kab.co.kr/OpenAPI_ToolInstallPackage/service/rest/LfrPrcIndexSvc/getLfrPrcIndex?startmonth=201301&endmonth=201312&region=11000&serviceKey=IPdNBMVqicr7iQwD3Q7A9cDokBT6I4pYWeloB%2BBtCpRkFBIKvmZbl2trNWZ8N0x%2Bl1IufqHYNjCQQpLWMmKVUQ%3D%3D
# fullUrl is http://openapi.kab.co.kr/OpenAPI_ToolInstallPackage/service/rest/LfrPrcIndexSvc/getLfrPrcIndex?startmonth=201301&endmonth=201312&region=11000&serviceKey=IPdNBMVqicr7iQwD3Q7A9cDokBT6I4pYWeloB%2BBtCpRkFBIKvmZbl2trNWZ8N0x%2Bl1IufqHYNjCQQpLWMmKVUQ%3D%3D
# ../../data/outbound/359_한국감정원 지가지수 현황/359_한국감정원 지가지수 현황.csv
# 359_한국감정원 지가지수 현황참고문서 Error
# unknown url type: ''
# http://api.hf.go.kr:8090/service/rest/HfMbsInterestInfo/getHfMbsInterest?serviceKey=IPdNBMVqicr7iQwD3Q7A9cDokBT6I4pYWeloB%2BBtCpRkFBIKvmZbl2trNWZ8N0x%2Bl1IufqHYNjCQQpLWMmKVUQ%3D%3D
# fullUrl is http://api.hf.go.kr:8090/service/rest/HfMbsInterestInfo/getHfMbsInterest?serviceKey=IPdNBMVqicr7iQwD3Q7A9cDokBT6I4pYWeloB%2BBtCpRkFBIKvmZbl2trNWZ8N0x%2Bl1IufqHYNjCQQpLWMmKVUQ%3D%3D
# ../../data/outbound/360_한국주택금융공사 주택저당증권(MBS) 현황/360_한국주택금융공사 주택저당증권(MBS) 현황.csv
# 360_한국주택금융공사 주택저당증권(MBS) 현황참고문서 Error
# unknown url type: ''
# http://api.hf.go.kr:8090/service/rest/HfMbbInterestInfo/getHfMbbInterest?serviceKey=IPdNBMVqicr7iQwD3Q7A9cDokBT6I4pYWeloB%2BBtCpRkFBIKvmZbl2trNWZ8N0x%2Bl1IufqHYNjCQQpLWMmKVUQ%3D%3D
# fullUrl is http://api.hf.go.kr:8090/service/rest/HfMbbInterestInfo/getHfMbbInterest?serviceKey=IPdNBMVqicr7iQwD3Q7A9cDokBT6I4pYWeloB%2BBtCpRkFBIKvmZbl2trNWZ8N0x%2Bl1IufqHYNjCQQpLWMmKVUQ%3D%3D
# ../../data/outbound/361_한국주택금융공사 주택저당채권담보부채권(MBB) 현황/361_한국주택금융공사 주택저당채권담보부채권(MBB) 현황.csv
# 361_한국주택금융공사 주택저당채권담보부채권(MBB) 현황참고문서 Error
# unknown url type: ''
# https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001420536&fileDetailSn=1&publicDataDetailPk=uddi:00ee36d5-623c-42f1-8e98-be79b0aeea41_201712281457
# fullUrl is https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001420536&fileDetailSn=1&publicDataDetailPk=uddi:00ee36d5-623c-42f1-8e98-be79b0aeea41_201712281457
# ../../data/outbound/363_사업자보증 현황/363_사업자보증 현황.csv
# 363_사업자보증 현황참고문서 Error
# unknown url type: ''
# https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001420108&fileDetailSn=1&publicDataDetailPk=uddi:9fc55333-88a9-411f-a9a7-f70385d39712_201712281342
# fullUrl is https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001420108&fileDetailSn=1&publicDataDetailPk=uddi:9fc55333-88a9-411f-a9a7-f70385d39712_201712281342
# ../../data/outbound/378_디딤돌대출현황/378_디딤돌대출현황.csv
# 378_디딤돌대출현황참고문서 Error
# unknown url type: ''
# https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001420537&fileDetailSn=1&publicDataDetailPk=uddi:1187ad78-3933-43e9-92ae-9ed15c7096d8_201712281357
# fullUrl is https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001420537&fileDetailSn=1&publicDataDetailPk=uddi:1187ad78-3933-43e9-92ae-9ed15c7096d8_201712281357
# ../../data/outbound/385_주택금융관련 지수/385_주택금융관련 지수.csv
# 385_주택금융관련 지수참고문서 Error
# unknown url type: ''
# https://www.data.go.kr/pubn/dat/IrosUseData/detectPersonalInfo.do
# fullUrl is https://www.data.go.kr/pubn/dat/IrosUseData/detectPersonalInfo.do
# ../../data/outbound/386_주택금융신용보증 현황/386_주택금융신용보증 현황.csv
# 386_주택금융신용보증 현황참고문서 Error
# unknown url type: ''
# https://www.data.go.kr/subMain.jsp#
# fullUrl is https://www.data.go.kr/subMain.jsp#aiaNgZ3r3nPeUj5%2FKuJ10ZNRmyePXavavOu8RZwO%2F84LnOn5KxhWa1%2F5nwxk0Y4M10W0fjCK1SksOQeQsdMu6A%3D%3D&type=xml
# Empty DataFrame
# Columns: []
# Index: []
# ../../data/outbound/389_지가지수(연도별, 용도지역별, 월별, 월별_읍면동별, 이용상황별)/389_지가지수(연도별, 용도지역별, 월별, 월별_읍면동별, 이용상황별).csv
# 100% [........................................................] 587496 / 587496https://www.data.go.kr/subMain.jsp#
# fullUrl is https://www.data.go.kr/subMain.jsp#aiaNgZ3r3nPeUj5%2FKuJ10ZNRmyePXavavOu8RZwO%2F84LnOn5KxhWa1%2F5nwxk0Y4M10W0fjCK1SksOQeQsdMu6A%3D%3D
# Empty DataFrame
# Columns: []
# Index: []
# ../../data/outbound/390_지가변동률(연도별, 용도지역별, 월별, 월별_읍면동별, 이용상황별)/390_지가변동률(연도별, 용도지역별, 월별, 월별_읍면동별, 이용상황별).csv
# 390_지가변동률(연도별, 용도지역별, 월별, 월별_읍면동별, 이용상황별)참고문서 Error
# HTTP Error 500: Internal Server Error

# %%
    
# 라이브러리 선언
import requests #Used to service API connection
from lxml import html #Used to parse XML
from bs4 import BeautifulSoup #Used to read XML table on webpage
import pandas as pd

# 시험데이터
# 아파트 매매 실거래가 상세자료

baseUrl = "http://openapi.kab.co.kr/OpenAPI_ToolInstallPackage/service/rest/LfrPriceSvc/getLfrPriceIndexYear"

serviceKey = "aiaNgZ3r3nPeUj5%2FKuJ10ZNRmyePXavavOu8RZwO%2F84LnOn5KxhWa1%2F5nwxk0Y4M10W0fjCK1SksOQeQsdMu6A%3D%3D"

#parameter = "startyear=2010&endyear=2018&region=11000"

# make url (example)
# developer can attach full url here
url = baseUrl+"?"+"serviceKey="+serviceKey+"&"+parameter

response = requests.get(url)
response

Data = BeautifulSoup(response.text, 'lxml-xml')
result = []
rows = 0
columnName = []
# search Item all item tag
iterData = Data.find_all('item')
iterData

for item in iterData:
        item_list = []
        # Fill the value in one row
        for tag in item.find_all():
            try:
                tagname = tag.name
                if rows == 0:
                    columnName.append(tagname)
                item_list.append(item.find(tagname).text)
            except Exception as e:
                print("This row will be ignored. ",item_list)
        rows = rows + 1
        result.append(item_list)

result

finalResult = pd.DataFrame(result)
finalResult.columns = columnName
print(finalResult)
finalResult.to_csv('./abc2.csv')
# Out:
#   regionCd regionNm                                              rsRow
# 0    11000       서울  2013,92.337|2014,94.795|2015,97.344|2016,100.2...
